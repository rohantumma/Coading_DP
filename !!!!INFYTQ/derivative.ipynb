# %%
count=int(input("ENTER the COUNT OF derivate : "))
row=4

mat=[]

for i in range (0,row):
    mat.append([])

for i in range (0,row):
    for j in range (0,count+1):
        mat[i].append(j)
        mat[i][j]=0;

for i in range(0,count):
        mat[0][i]=int(input())


for i in range (0,row):
    for j in range (0,count,1):
                print(mat[i][j+1]-mat[i][j])
                if(i!=3):
                    mat[i+1][j]=mat[i][j+1]-mat[i][j]
                #if(mat[i][j+1]==mat[i][j+2]==mat[i][j+3]):
                    #goto m
print('hhds')
for i in range(row-1,0,-1):
    for j in range(count,0,-1):
        if(i!=0 and j!=3):
            print(mat[i][j]," ",mat[i - 1][row - i])
            k=mat[i][j]+mat[i-1][row-i]
            mat[0][count]=mat[i][j] + mat[i - 1][row - i]
            print("\n k=",k)
mat[0][count]=mat[0][count]+mat[row-1][0]
print(mat)
# Out:
# ENTER the COUNT OF derivate : 4
# 1
# 3
# 8
# 17
# 2
# 5
# 9
# -17
# 3
# 4
# -26
# 17
# 1
# -30
# 43
# -17
# -31
# 73
# -60
# 17
# hhds
# 0   4
#
#  k= 4
# 43   4
#
#  k= 47
# -30   4
#
#  k= -26
# 0   9
#
#  k= 9
# -26   9
#
#  k= -17
# 4   9
#
#  k= 13
# 0   17
#
#  k= 17
# 9   17
#
#  k= 26
# 5   17
#
#  k= 22
# [[1, 3, 8, 17, 23], [2, 5, 9, -17, 0], [3, 4, -26, 17, 0], [1, -30, 43, -17, 0]]

# %%
count=int(input("ENTER the COUNT OF derivate : "))
row=count

mat=[]

for i in range (0,row):
    mat.append([])

for i in range (0,row):
    for j in range (0,count+1):
        mat[i].append(j)
        mat[i][j]=0;

for i in range(0,count):
        mat[0][i]=int(input())


for i in range (0,row):
    for j in range (0,count,1):
            if(mat[i][j+1]!=0):
                #print(mat[i][j+1]-mat[i][j])
                if(i!=3):
                    mat[i+1][j]=mat[i][j+1]-mat[i][j]
                #if(mat[i][j+1]==mat[i][j+2]==mat[i][j+3]):
                    #goto m
print('YOUR SERIES IS=')
for i in range(row-1,0,-1):
    for j in range(count,0,-1):
        if(i!=0 and j!=3):
            #print(mat[i][j]," ",mat[i - 1][row - i])
            k=k+mat[i][j]+mat[i-1][row-i]
            mat[0][count]=mat[i][j] + mat[i - 1][row - i]
            #print("\n k=",k)
mat[0][count]=mat[0][count]+mat[row-1][0]
print(mat[0])
# Out:
# ENTER the COUNT OF derivate : 4
# 3
# 5
# 7
# 9
# YOUR SERIES IS=
# [3, 5, 7, 9, 11]
